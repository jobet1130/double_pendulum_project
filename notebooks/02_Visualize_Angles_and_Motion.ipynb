# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path 

sns.set_style("whitegrid")
# %matplotlib inline

# %%
data_path = Path("../data/processed/double_pendulum_processed.csv")

if not data_path.exists():
    raise FileNotFoundError(f"❌ Processed data not found at: {data_path}")

df = pd.read_csv(data_path)
df.head()
# Out:
#    time    theta1    theta2    omega1    omega2        x1        y1        x2  \
# 0  0.00  2.094395 -0.174533  0.000000  0.000000  0.866025  0.500000  0.692377
# 1  0.01  2.093894 -0.174296 -0.100185  0.047317  0.866276  0.499566  0.692861
# 2  0.02  2.092391 -0.173588 -0.200410  0.094385  0.867026  0.498264  0.694308
# 3  0.03  2.089886 -0.172411 -0.300715  0.140950  0.868271  0.496090  0.696713
# 4  0.04  2.086377 -0.170773 -0.401144  0.186767  0.870007  0.493040  0.700063
#
#          y2        KE         PE        TME
# 0 -0.484808  0.000000  29.579036  29.579036
# 1 -0.485283  0.014201  29.570121  29.584322
# 2 -0.486708  0.056734  29.543363  29.600098
# 3 -0.489084  0.127392  29.498728  29.626120
# 4 -0.492414  0.225836  29.436146  29.661983

# %%
plt.figure(figsize=(12, 5))
plt.plot(df["time"], df["theta1"], label=r"$\theta_1$", color="royalblue")
plt.plot(df["time"], df["theta2"], label=r"$\theta_2$", color="tomato")
plt.title("Angular Position vs. Time", fontsize=14)
plt.xlabel("Time (s)")
plt.ylabel("Angle (rad)")
plt.legend()
plt.tight_layout()

plot_dir = Path("../plots")
plot_dir.mkdir(parents=True, exist_ok=True)
theta_plot = plot_dir / "angle_vs_time.png"
plt.savefig(theta_plot)
plt.show()

print(f"✅ Saved: {theta_plot}")
# Out:
# ✅ Saved: plots\angle_vs_time.png

# %%
plt.figure(figsize=(12, 5))
plt.plot(df["time"], df["omega1"], label=r"$\omega_1$", color="green")
plt.plot(df["time"], df["omega2"], label=r"$\omega_2$", color="orange")
plt.title("Angular Velocity vs. Time", fontsize=14)
plt.xlabel("Time (s)")
plt.ylabel("Angular Velocity (rad/s)")
plt.legend()
plt.tight_layout()

omega_plot = plot_dir / "omega_vs_time.png"
plt.savefig(omega_plot)
plt.show()

print(f"✅ Saved: {omega_plot}")
# Out:
# ✅ Saved: plots\omega_vs_time.png
